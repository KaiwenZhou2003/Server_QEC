# %% [markdown]
# 72,12,6

# %%
# 由于执行状态已重置，需要重新导入库并定义数据
import numpy as np
import matplotlib.pyplot as plt

# 重新定义数据
x_values = np.array([5.00E-04, 6.00E-04, 7.00E-04, 8.00E-04, 9.00E-04, 
                     1.00E-03, 2.00E-03, 3.00E-03, 4.00E-03, 5.00E-03])

bp_osd_72 = np.array([2.13E-06, 3.33E-06, 8.33E-06, 1.16E-05, 1.33E-05, 
                       1.67E-05, 6.67E-05, 2.00E-04, 4.67E-04, 8.70E-04])
bp_72 = np.array([4.50E-05, 5.83E-05, 8.33E-05, 1.10E-04, 1.33E-04, 
                   1.50E-04, 5.84E-04, 1.40E-03, 1.90E-03, 3.30E-03])
ours_72 = np.array([3.33E-06, 8.33E-06, 1.33E-05, 1.66E-05, 1.66E-05, 
                     2.45E-05, 6.67E-05, 1.80E-04, 4.10E-04, 7.34E-04])

# 画图
plt.figure(figsize=(8, 5))
plt.xscale("log")
plt.yscale("log")

# 绘制数据曲线
plt.plot(x_values, bp_osd_72, 'o-', label="BP+OSD", color='blue')
plt.plot(x_values, bp_72, 's-', label="BP", color='red')
plt.plot(x_values, ours_72, 'd-', label="Ours", color='green')

# 设置图例、标题和标签
plt.xlabel("Error Probability", fontsize=12)
plt.ylabel("Logical Error Rate", fontsize=12)
plt.title("Decoding Performance for (72,12,6)", fontsize=14)
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# 显示图像
plt.savefig("BBcode/72_12_6.svg", format="svg", dpi=300)
plt.show()

# %% [markdown]
# 90,8,10

# %%
# 重新定义新的数据集
bp_osd_new = np.array([7.00E-06, 7.00E-06, 8.00E-06, 1.30E-05, 1.40E-05, 
                        2.00E-05, 5.00E-05, 1.00E-04, 3.40E-04, 6.70E-04])
bp_new = np.array([3.80E-05, 5.40E-05, 7.50E-05, 9.70E-05, 1.13E-04, 
                    1.70E-04, 5.90E-04, 1.61E-03, 2.12E-03, 3.41E-03])
ours_new = np.array([5.00E-06, 5.00E-06, 7.00E-06, 1.00E-05, 1.00E-05, 
                      1.00E-05, 6.00E-05, 1.00E-04, 2.90E-04, 4.90E-04])

# 画图
plt.figure(figsize=(8, 5))
plt.xscale("log")
plt.yscale("log")

# 绘制数据曲线
plt.plot(x_values, bp_osd_new, 'o-', label="BP+OSD", color='blue')
plt.plot(x_values, bp_new, 's-', label="BP", color='red')
plt.plot(x_values, ours_new, 'd-', label="Ours", color='green')

# 设置图例、标题和标签
plt.xlabel("Error Probability", fontsize=12)
plt.ylabel("Logical Error Rate", fontsize=12)
plt.title("Decoding Performance (90,8,10)", fontsize=14)
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# 显示图像
plt.show()

# %% [markdown]
# 108,8,10

# %%
# 重新定义新的数据集（最新数据）
bp_osd_latest = np.array([5.00E-06, 9.00E-06, 1.40E-05, 1.70E-05, 2.00E-05, 
                           3.00E-05, 1.00E-04, 2.30E-04, 5.41E-04, 8.53E-04])
bp_latest = np.array([5.40E-05, 7.50E-05, 9.70E-05, 1.30E-04, 1.62E-04, 
                       1.80E-04, 6.90E-04, 1.84E-03, 2.78E-03, 4.39E-03])
ours_latest = np.array([7.00E-06, 1.00E-05, 1.60E-05, 1.90E-05, 2.10E-05, 
                         2.00E-05, 8.00E-05, 2.10E-04, 3.90E-04, 5.71E-04])

# 画图
plt.figure(figsize=(8, 5))
plt.xscale("log")
plt.yscale("log")

# 绘制数据曲线
plt.plot(x_values, bp_osd_latest, 'o-', label="BP+OSD", color='blue')
plt.plot(x_values, bp_latest, 's-', label="BP", color='red')
plt.plot(x_values, ours_latest, 'd-', label="Ours", color='green')

# 设置图例、标题和标签
plt.xlabel("Error Probability", fontsize=12)
plt.ylabel("Logical Error Rate", fontsize=12)
plt.title("Decoding Performance (Latest Data)", fontsize=14)
plt.legend()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)

# 显示图像
plt.show()
